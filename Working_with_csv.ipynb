# %% [markdown]
#  # 1.Importing panda library

# %%
import pandas as pd

# %% [markdown]
# # 2.Openning a local csv file

# %%
df=pd.read_csv('/content/aug_train.csv')

# %% [markdown]
# # 3.Importing csv file from URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# # Sep parameter
#   specialy use tsv type file where the data seperated with tab so u have to give 't'

# %%
pd.read_csv('/content/movie_titles_metadata.tsv',sep='\t')
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %% [markdown]
# # 5.Index_col parameter

# %%
pd.read_csv('/content/aug_train.csv',index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 2785          city_21                   0.624   Male   No relevent experience
# 16221        city_102                   0.804   Male  Has relevent experience
# 15749        city_136                   0.897    NaN  Has relevent experience
# 23759         city_21                   0.624    NaN   No relevent experience
# 24692        city_142                   0.727   Male  Has relevent experience
#
# ...

# %% [markdown]
# # 6.Header parameter
#   use tb karo jb column names rows ki trah use ho rhe ho

# %%
pd.read_csv('test.csv',header=1)

# %% [markdown]
# # 7.use_cols parameter

# %%
pd.read_csv('/content/aug_train.csv',usecols=['enrollee_id','gender','education_level'])
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %% [markdown]
# # 8.Squeeze parameters

# %%
pd.read_csv('/content/aug_train.csv',usecols=['gender'],squeeze=True)
# Out:
# <ipython-input-14-703fb75caeda>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv('/content/aug_train.csv',usecols=['gender'],squeeze=True)
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %% [markdown]
# # 9.Skiprows/n rows Parameter
#
# n rows restrict the number of rows which you want to work on
# ---

# %%
pd.read_csv('/content/aug_train.csv',skiprows=[0,1],nrows=100)
# Out:
#     29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0   11561   city_21               0.624   NaN   No relevent experience
# 1   33241  city_115               0.789   NaN   No relevent experience
# 2     666  city_162               0.767  Male  Has relevent experience
# 3   21651  city_176               0.764   NaN  Has relevent experience
# 4   28806  city_160               0.920  Male  Has relevent experience
# ..    ...       ...                 ...   ...                      ...
# 95  11184   city_74               0.579   NaN   No relevent experience
# 96   7016   city_65               0.802  Male  Has relevent experience
# 97   8695   city_11               0.550  Male  Has relevent experience
# 98   6172   city_11               0.550  Male  Has relevent experience
# 99  14672  city_173               0.878   NaN   No relevent experience
#
#        no_enrollment     Graduate             STEM   15    50-99  \
# ...

# %% [markdown]
# # 10.Encoding parameter

# %%
pd.read_csv('/content/zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # 11.Skip bad lines
# If there is error in any line the line will skip

# %%
pd.read_csv('/content/zomato.csv',encoding='latin-1',error_bad_lines=False)
# Out:
# <ipython-input-24-8a1fd95672a1>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   pd.read_csv('/content/zomato.csv',encoding='latin-1',error_bad_lines=False)
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# ...

# %% [markdown]
# # 12.Dtype parameter

# %%
from pandas.core.arrays.arrow import dtype
pd.read_csv("aug_train.csv",dtype={'target':int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# ...

# %% [markdown]
# # 13.Handling Dates

# %%
pd.read_csv('/content/IPL_matches.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               322 non-null    int64
#  1   Season           322 non-null    object
#  2   city             315 non-null    object
#  3   date             322 non-null    datetime64[ns]
#  4   team1            322 non-null    object
#  5   team2            322 non-null    object
#  6   toss_winner      322 non-null    object
#  7   toss_decision    322 non-null    object
#  8   result           322 non-null    object
#  9   dl_applied       322 non-null    int64
#  10  winner           319 non-null    object
#  11  win_by_runs      322 non-null    int64
#  12  win_by_wickets   322 non-null    int64
#  13  player_of_match  319 non-null    object
#  14  venue            322 non-null    object
#  15  umpire1          320 non-null    object
# ...

# %%
# rename the given names
def rename(name):
  if name=="Mumbai Indians":
    return "MI"
  else:
    return name

# %%
rename("Mumbai Indians")
# Out:
# 'MI'

# %%
pd.read_csv("/content/IPL_matches.csv",converters={'team1':rename})
# Out:
#       id    Season           city        date                  team1  \
# 0      1  IPL-2014      Abu Dhabi  18-04-2014    Sunrisers Hyderabad
# 1      2  IPL-2014            NaN  19-04-2014                     MI
# 2      3  IPL-2014            NaN  19-04-2014  Kolkata Knight Riders
# 3      4  IPL-2014        Sharjah  20-04-2014       Rajasthan Royals
# 4      5  IPL-2014      Abu Dhabi  21-04-2014    Chennai Super Kings
# ..   ...       ...            ...         ...                    ...
# 317  318  IPL-2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 318  319  IPL-2019        Chennai  07-05-2019    Chennai Super Kings
# 319  320  IPL-2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 320  321  IPL-2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 321  322  IPL-2019      Hyderabad  12-05-2019                     MI
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # 15. na_values parameters

# %%
pd.read_csv('aug_train.csv',na_values=['Male'])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # 16. Loading a huge dataset in chunks

# %%
dfs=pd.read_csv('aug_train.csv',chunksize=5000)

# %%
for chunk in dfs:
  print(chunk.shape)
# Out:
# (4158, 14)
